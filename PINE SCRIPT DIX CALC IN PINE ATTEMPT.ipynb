# %%
for (num,item) in enumerate(ticker):
    print("      sym{} = input(title=\"Symbol {}\", type=string, defval=\"{}\")".format(str(num+1),str(num+1),item))
# Out:
#       sym1 = input(title="Symbol 1", type=string, defval="MSFT")
#       sym2 = input(title="Symbol 2", type=string, defval="AAPL")
#       sym3 = input(title="Symbol 3", type=string, defval="AMZN")
#       sym4 = input(title="Symbol 4", type=string, defval="FB")
#       sym5 = input(title="Symbol 5", type=string, defval="BRK.B")
#       sym6 = input(title="Symbol 6", type=string, defval="JNJ")
#       sym7 = input(title="Symbol 7", type=string, defval="GOOG")
#       sym8 = input(title="Symbol 8", type=string, defval="GOOGL")
#       sym9 = input(title="Symbol 9", type=string, defval="PG")
#       sym10 = input(title="Symbol 10", type=string, defval="JPM")
#       sym11 = input(title="Symbol 11", type=string, defval="V")
#       sym12 = input(title="Symbol 12", type=string, defval="T")
#       sym13 = input(title="Symbol 13", type=string, defval="VZ")
#       sym14 = input(title="Symbol 14", type=string, defval="UNH")
# ...

# %%
i = 1
while i < 506:
    print("QS{} = security(\"QUANDL:FINRA/FNSQ_\" + sym{} + \"|0\", \"D\", close)".format(str(i),str(i)))
    print("NS{} = security(\"QUANDL:FINRA/FNYX_\" + sym{} + \"|0\", \"D\", close)".format(str(i),str(i)))
    print("S{} = QS{} + NS{}".format(str(i),str(i),str(i)))
    i += 1
i = 1
# Out:
# QS1 = security("QUANDL:FINRA/FNSQ_" + sym1 + "|0", "D", close)
# NS1 = security("QUANDL:FINRA/FNYX_" + sym1 + "|0", "D", close)
# S1 = QS1 + NS1
# QS2 = security("QUANDL:FINRA/FNSQ_" + sym2 + "|0", "D", close)
# NS2 = security("QUANDL:FINRA/FNYX_" + sym2 + "|0", "D", close)
# S2 = QS2 + NS2
# QS3 = security("QUANDL:FINRA/FNSQ_" + sym3 + "|0", "D", close)
# NS3 = security("QUANDL:FINRA/FNYX_" + sym3 + "|0", "D", close)
# S3 = QS3 + NS3
# QS4 = security("QUANDL:FINRA/FNSQ_" + sym4 + "|0", "D", close)
# NS4 = security("QUANDL:FINRA/FNYX_" + sym4 + "|0", "D", close)
# S4 = QS4 + NS4
# QS5 = security("QUANDL:FINRA/FNSQ_" + sym5 + "|0", "D", close)
# NS5 = security("QUANDL:FINRA/FNYX_" + sym5 + "|0", "D", close)
# S5 = QS5 + NS5
# QS6 = security("QUANDL:FINRA/FNSQ_" + sym6 + "|0", "D", close)
# NS6 = security("QUANDL:FINRA/FNYX_" + sym6 + "|0", "D", close)
# S6 = QS6 + NS6
# QS7 = security("QUANDL:FINRA/FNSQ_" + sym7 + "|0", "D", close)
# ...

# %%
print("sTotal = ")
for (num,item) in enumerate(ticker):
    print("S{} + ".format(str(num+1)), end="")
# Out:
# sTotal =
# ...

# %%
i = 1
while i < 506:
    print("QV{} = security(\"QUANDL:FINRA/FNSQ_\" + sym{} + \"|2\", \"D\", close)".format(str(i),str(i)))
    print("NV{} = security(\"QUANDL:FINRA/FNYX_\" + sym{} + \"|2\", \"D\", close)".format(str(i),str(i)))
    print("V{} = QV{} + NV{}".format(str(i),str(i),str(i)))
    i += 1
# Out:
# QV1 = security("QUANDL:FINRA/FNSQ_" + sym1 + "|2", "D", close)
# NV1 = security("QUANDL:FINRA/FNYX_" + sym1 + "|2", "D", close)
# V1 = QV1 + NV1
# QV2 = security("QUANDL:FINRA/FNSQ_" + sym2 + "|2", "D", close)
# NV2 = security("QUANDL:FINRA/FNYX_" + sym2 + "|2", "D", close)
# V2 = QV2 + NV2
# QV3 = security("QUANDL:FINRA/FNSQ_" + sym3 + "|2", "D", close)
# NV3 = security("QUANDL:FINRA/FNYX_" + sym3 + "|2", "D", close)
# V3 = QV3 + NV3
# QV4 = security("QUANDL:FINRA/FNSQ_" + sym4 + "|2", "D", close)
# NV4 = security("QUANDL:FINRA/FNYX_" + sym4 + "|2", "D", close)
# V4 = QV4 + NV4
# QV5 = security("QUANDL:FINRA/FNSQ_" + sym5 + "|2", "D", close)
# NV5 = security("QUANDL:FINRA/FNYX_" + sym5 + "|2", "D", close)
# V5 = QV5 + NV5
# QV6 = security("QUANDL:FINRA/FNSQ_" + sym6 + "|2", "D", close)
# NV6 = security("QUANDL:FINRA/FNYX_" + sym6 + "|2", "D", close)
# V6 = QV6 + NV6
# QV7 = security("QUANDL:FINRA/FNSQ_" + sym7 + "|2", "D", close)
# ...

# %%
print("vTotal = ")
for (num,item) in enumerate(ticker):
    print("V{} + ".format(str(num+1)), end="")
# Out:
# vTotal =
# ...
